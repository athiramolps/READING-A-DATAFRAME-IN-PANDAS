# %% [markdown]
# # **IMPORTING LIBRARIES**

# %%
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import scipy as sp
import plotly.express as px

# %%
data=pd.read_csv('/content/List of countries by carbon dioxide emissions.csv')
data
# Out:
#                            Country  Fossil CO2 emissions(Mt CO2)  Unnamed: 2  \
# 0                              NaN                      1990.000    2005.000
# 1                            World                     22674.116   30049.809
# 2    World  International Aviation                       258.941     422.777
# 3    World  International Shipping                       371.804     572.169
# 4                      Afghanistan                         2.546       1.063
# ..                             ...                           ...         ...
# 208                        Vietnam                        20.182      99.231
# 209                 Western Sahara                         0.144       0.227
# 210                          Yemen                         6.887      21.768
# 211                         Zambia                         2.955       2.457
# 212                       Zimbabwe                        17.178      11.388
#
# ...

# %% [markdown]
# # **UNDERSTANDING DATA**

# %% [markdown]
# **1. BASIC CHECKING**

# %% [markdown]
# READ MAXIMUM ROWS AND COLUMNS IN NUMBER

# %%
pd.set_option('display.max.rows', 213)
pd.set_option('display.max.columns', 7)

# %% [markdown]
# DATA INFORMATION

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 213 entries, 0 to 212
# Data columns (total 10 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   Country                       212 non-null    object
#  1   Fossil CO2 emissions(Mt CO2)  213 non-null    float64
#  2   Unnamed: 2                    213 non-null    float64
#  3   Unnamed: 3                    213 non-null    float64
#  4   Fossil CO2 emissions          213 non-null    object
#  5   Unnamed: 5                    213 non-null    object
#  6   2017  Fossil CO2 emissions    211 non-null    object
#  7   Unnamed: 7                    211 non-null    object
#  8   2018 CO2 emissions            186 non-null    object
#  9   Unnamed: 9                    185 non-null    object
# dtypes: float64(3), object(7)
# memory usage: 16.8+ KB

# %% [markdown]
# DATA SHAPE

# %%
data.shape
# Out:
# (213, 10)

# %% [markdown]
#    READ FIRST 5 ROWS

# %%
data.head(5)
# Out:
#                          Country  Fossil CO2 emissions(Mt CO2)  Unnamed: 2  \
# 0                            NaN                      1990.000    2005.000
# 1                          World                     22674.116   30049.809
# 2  World  International Aviation                       258.941     422.777
# 3  World  International Shipping                       371.804     572.169
# 4                    Afghanistan                         2.546       1.063
#
#    ...                Unnamed: 7    2018 CO2 emissions            Unnamed: 9
# 0  ...  Per capita(t CO2/cap/yr)  Total including LUCF  Total excluding LUCF
# 1  ...                       4.9              36431.11              35247.21
# 2  ...                       NaN                   NaN                   NaN
# 3  ...                       NaN                   NaN                   NaN
# 4  ...                       0.3                  7.59                  7.44
#
# [5 rows x 10 columns]

# %% [markdown]
#   READ LAST 5 ROWS

# %%
data.tail(10)
# Out:
#             Country  Fossil CO2 emissions(Mt CO2)  Unnamed: 2  ...  \
# 203   United States                      5085.897    5971.571  ...
# 204         Uruguay                         3.893       5.483  ...
# 205      Uzbekistan                       123.106     116.386  ...
# 206         Vanuatu                         0.130       0.063  ...
# 207       Venezuela                       109.268     152.464  ...
# 208         Vietnam                        20.182      99.231  ...
# 209  Western Sahara                         0.144       0.227  ...
# 210           Yemen                         6.887      21.768  ...
# 211          Zambia                         2.955       2.457  ...
# 212        Zimbabwe                        17.178      11.388  ...
#
#      Unnamed: 7 2018 CO2 emissions Unnamed: 9
# 203        15.7            4749.57     4981.3
# 204           2               4.75       6.52
# 205           3             108.72     112.09
# ...

# %% [markdown]
# DATA TYPES

# %%
data.dtypes
# Out:
# Country                          object
# Fossil CO2 emissions(Mt CO2)    float64
# Unnamed: 2                      float64
# Unnamed: 3                      float64
# Fossil CO2 emissions             object
# Unnamed: 5                       object
# 2017  Fossil CO2 emissions       object
# Unnamed: 7                       object
# 2018 CO2 emissions               object
# Unnamed: 9                       object
# dtype: object

# %% [markdown]
# SEE NUMERIC COLUMNS

# %%
pd.set_option('display.max_columns',None)
data.head()
# Out:
#                          Country  Fossil CO2 emissions(Mt CO2)  Unnamed: 2  \
# 0                            NaN                      1990.000    2005.000
# 1                          World                     22674.116   30049.809
# 2  World  International Aviation                       258.941     422.777
# 3  World  International Shipping                       371.804     572.169
# 4                    Afghanistan                         2.546       1.063
#
#    Unnamed: 3 Fossil CO2 emissions                Unnamed: 5  \
# 0    2017.000     2017(% of world)  2017 vs 1990: change (%)
# 1   37077.404              100.00%                    63.50%
# 2     543.381                1.47%                   109.80%
# 3     677.248                1.83%                    82.20%
# 4      11.422                0.03%                   348.60%
#
#     2017  Fossil CO2 emissions                Unnamed: 7  \
# 0  Per land area(t CO2/km2/yr)  Per capita(t CO2/cap/yr)
# ...

# %% [markdown]
# SEE NULL VALUES

# %%
data.isnull().sum().sort_values(ascending=False)
# Out:
# Unnamed: 9                      28
# 2018 CO2 emissions              27
# 2017  Fossil CO2 emissions       2
# Unnamed: 7                       2
# Country                          1
# Fossil CO2 emissions(Mt CO2)     0
# Unnamed: 2                       0
# Unnamed: 3                       0
# Fossil CO2 emissions             0
# Unnamed: 5                       0
# dtype: int64

# %% [markdown]
# SEE DUPLICATED DATA

# %%
data[data.duplicated(keep=False)]
# Out:
# Empty DataFrame
# Columns: [Country, Fossil CO2 emissions(Mt CO2), Unnamed: 2, Unnamed: 3, Fossil CO2 emissions, Unnamed: 5, 2017  Fossil CO2 emissions, Unnamed: 7, 2018 CO2 emissions, Unnamed: 9]
# Index: []

# %% [markdown]
# SEE DUPLICATE VALUES COUNT IN NUMBER

# %%
data.duplicated().sum()
# Out:
# 0

# %% [markdown]
# SEE ALL COLUMN LABELS OF DATASET

# %%
data.columns
# Out:
# Index(['Country', 'Fossil CO2 emissions(Mt CO2)', 'Unnamed: 2', 'Unnamed: 3',
#        'Fossil CO2 emissions', 'Unnamed: 5', '2017  Fossil CO2 emissions',
#        'Unnamed: 7', '2018 CO2 emissions', 'Unnamed: 9'],
#       dtype='object')

# %% [markdown]
#   DESCRIPTIVE STATISTICS SUMMARY

# %%
data.describe()
# Out:
#        Fossil CO2 emissions(Mt CO2)    Unnamed: 2    Unnamed: 3
# count                    213.000000    213.000000    213.000000
# mean                     243.016573    311.421516    374.298817
# std                     1636.415890   2161.040668   2680.033230
# min                        0.001000      0.002000      0.002000
# 25%                        0.684000      1.119000      1.771000
# 50%                        5.851000      7.806000     11.422000
# 75%                       57.242000     61.396000     72.249000
# max                    22674.116000  30049.809000  37077.404000

# %% [markdown]
# GET THE FULL DETAILS OF A SINGLE COLUMN

# %%
data['Country']
# Out:
# 0                                               NaN
# 1                                             World
# 2                     World  International Aviation
# 3                     World  International Shipping
# 4                                       Afghanistan
# 5                                           Albania
# 6                                           Algeria
# 7                                            Angola
# 8                                          Anguilla
# 9                               Antigua and Barbuda
# 10                                        Argentina
# 11                                          Armenia
# 12                                            Aruba
# 13                                        Australia
# 14                                          Austria
# 15                                       Azerbaijan
# 16                                          Bahamas
# 17                                          Bahrain
# ...

# %% [markdown]
# GET THE 3 HEADS OF MULTIPLE COLUMNS

# %%
data[['Country','Fossil CO2 emissions(Mt CO2)']].head(3)
# Out:
#                          Country  Fossil CO2 emissions(Mt CO2)
# 0                            NaN                      1990.000
# 1                          World                     22674.116
# 2  World  International Aviation                       258.941

# %% [markdown]
# GET THE 3 TAILS OF MULTIPLE COLUMNS

# %%
data[['Country','Fossil CO2 emissions(Mt CO2)']].tail(3)
# Out:
#       Country  Fossil CO2 emissions(Mt CO2)
# 210     Yemen                         6.887
# 211    Zambia                         2.955
# 212  Zimbabwe                        17.178

# %% [markdown]
# SELECT A SINGLE ROW FROM  A SERIES BY LABEL

# %%
#loc method
data.loc[2]
# Out:
# Country                         World  International Aviation
# Fossil CO2 emissions(Mt CO2)                          258.941
# Unnamed: 2                                            422.777
# Unnamed: 3                                            543.381
# Fossil CO2 emissions                                    1.47%
# Unnamed: 5                                            109.80%
# 2017  Fossil CO2 emissions                                NaN
# Unnamed: 7                                                NaN
# 2018 CO2 emissions                                        NaN
# Unnamed: 9                                                NaN
# Name: 2, dtype: object

# %% [markdown]
# SELECT MULTIPLE ROWS FROM A SERIES BY LABEL

# %%
#loc
data.loc[[1,3]]
# Out:
#                          Country  Fossil CO2 emissions(Mt CO2)  Unnamed: 2  \
# 1                          World                     22674.116   30049.809
# 3  World  International Shipping                       371.804     572.169
#
#    Unnamed: 3 Fossil CO2 emissions Unnamed: 5 2017  Fossil CO2 emissions  \
# 1   37077.404              100.00%     63.50%                         73
# 3     677.248                1.83%     82.20%                        NaN
#
#   Unnamed: 7 2018 CO2 emissions Unnamed: 9
# 1        4.9           36431.11   35247.21
# 3        NaN                NaN        NaN

# %% [markdown]
# SELECTING A SUBSET OF COLUMNS FROM A SINGLE ROW

# %%
data.loc[2,['Fossil CO2 emissions(Mt CO2)','Unnamed: 2']]
# Out:
# Fossil CO2 emissions(Mt CO2)    258.941
# Unnamed: 2                      422.777
# Name: 2, dtype: object

# %% [markdown]
# GET ONLY SELECTED RANGE OF ROWS

# %%
data.loc[2:5]
# Out:
#                          Country  Fossil CO2 emissions(Mt CO2)  Unnamed: 2  \
# 2  World  International Aviation                       258.941     422.777
# 3  World  International Shipping                       371.804     572.169
# 4                    Afghanistan                         2.546       1.063
# 5                        Albania                         6.583       4.196
#
#    Unnamed: 3 Fossil CO2 emissions Unnamed: 5 2017  Fossil CO2 emissions  \
# 2     543.381                1.47%    109.80%                        NaN
# 3     677.248                1.83%     82.20%                        NaN
# 4      11.422                0.03%    348.60%                         18
# 5       5.026                0.01%    -23.70%                        175
#
#   Unnamed: 7 2018 CO2 emissions Unnamed: 9
# 2        NaN                NaN        NaN
# 3        NaN                NaN        NaN
# 4        0.3               7.59       7.44
# 5        1.7               5.32       5.56

# %% [markdown]
# GETTING A SINGLE VALUE BY SELECTING A SINGLE ROW AND SINGLE COLUMN OF DATA

# %%
data.loc[1,'Country']
# Out:
# 'World'

# %% [markdown]
# GETTING THE 201 ST ROW THE DATAFRAME

# %%
data.iloc[200]
# Out:
# Country                         Ukraine
# Fossil CO2 emissions(Mt CO2)     783.21
# Unnamed: 2                      354.429
# Unnamed: 3                      205.723
# Fossil CO2 emissions              0.55%
# Unnamed: 5                      -73.70%
# 2017  Fossil CO2 emissions          341
# Unnamed: 7                          4.7
# 2018 CO2 emissions               173.18
# Unnamed: 9                       185.37
# Name: 200, dtype: object

# %% [markdown]
# SELECTING THE SECOND,THIRD AND FOURTH ROWS OF THE FIRST COLUMNS OF THE DATAFRAME

# %%
data.iloc[1:4, 0:2]
# Out:
#                          Country  Fossil CO2 emissions(Mt CO2)
# 1                          World                     22674.116
# 2  World  International Aviation                       258.941
# 3  World  International Shipping                       371.804

# %% [markdown]
# GET A COUNT OF UNIQUE VALUES FOR A PARTICULAR COLUMN

# %%
print(data.columns)
# Out:
# Index(['Country', 'Fossil CO2 emissions(Mt CO2)', 'Unnamed: 2', 'Unnamed: 3',
#        'Fossil CO2 emissions', 'Unnamed: 5', '2017  Fossil CO2 emissions',
#        'Unnamed: 7', '2018 CO2 emissions', 'Unnamed: 9'],
#       dtype='object')

# %% [markdown]
# GET THE COUNT OF UNIQUE VALUES IN DESCENDING ORDER

# %%
print(data['Country'].value_counts())
# Out:
# World                                           1
# Namibia                                         1
# Netherlands                                     1
# New Caledonia                                   1
# New Zealand                                     1
# Nicaragua                                       1
# Niger                                           1
# Nigeria                                         1
# North Korea                                     1
# North Macedonia                                 1
# Norway                                          1
# Oman                                            1
# Pakistan                                        1
# Palau                                           1
# Panama                                          1
# Papua New Guinea                                1
# Paraguay                                        1
# Peru                                            1
# Philippines                                     1
# ...
